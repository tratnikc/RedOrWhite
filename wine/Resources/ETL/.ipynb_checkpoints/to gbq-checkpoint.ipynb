# %%
#  ETL to google big query

from google.oauth2 import service_account
import pandas as pd
import pandas_gbq
import json

## credentials
projectID = 'project-wine-308217'
datasetID = 'wine_dataset'
bigquery_uri = f'bigquery://{projectID}/{datasetID}'

credentials = service_account.Credentials.from_service_account_file('project-wine.json')

# step1
# open csv from_service_account_file
red= pd.read_csv('red.csv', encoding='latin-1')
white= pd.read_csv('white.csv', encoding='latin-1')



# step2
# load csv file to dataframe

# %%
red1=red[red.columns[0:13]]
white1=white[white.columns[0:13]]

# %%
red1.head()
# Out:
#                                 title  \
# 0     Mommessin Cuvee St Pierre Rouge
# 1  Folonari Valpolicella Classico DOC
# 2       Mouton Cadet Bordeaux Red AOC
# 3                Flat Rock Pinot Noir
# 4                     Ruffino Chianti
#
#                                                 link   price  \
# 0  https://www.lcbo.com/webapp/wcs/stores/servlet...   $8.30
# 1  https://www.lcbo.com/webapp/wcs/stores/servlet...  $14.80
# 2  https://www.lcbo.com/webapp/wcs/stores/servlet...  $17.35
# 3  https://www.lcbo.com/webapp/wcs/stores/servlet...  $22.95
# 4  https://www.lcbo.com/webapp/wcs/stores/servlet...  $15.30
#
#                                                  Img  \
# 0  /content/dam/lcbo/products/000513.jpg/jcr:cont...
# 1  /content/dam/lcbo/products/000828.jpg/jcr:cont...
# 2  /content/dam/lcbo/products/000943.jpg/jcr:cont...
# 3  /content/dam/lcbo/products/001545.jpg/jcr:cont...
# 4  /content/dam/lcbo/products/001743.jpg/jcr:cont...
#
#                                          Description    Bottle Size  \
# 0  This red blend is pale ruby in colour and offe...  750 mL bottle
# 1  Valpolicella is the classic red wine of Italy'...  750 mL bottle
# 2  From France's leading wine family, a wine that...  750 mL bottle
# 3  Innovative Flat Rock Cellars specializes in cr...  750 mL bottle
# 4  Ruffino's original wine, and one of the world'...  750 mL bottle
#
#   Alcohol/Vol:          Made In:                                By:  \
# 0          12%            France                     Mommessin S.A.
# 1        12.5%     Veneto, Italy                    Folonari S.P.A.
# 2          13%  Bordeaux, France  Baron Philippe De Rothschild S.A.
# 3          13%   Ontario, Canada                  Flat Rock Cellars
# 4          13%    Tuscany, Italy                     Ruffino S.R.L.
#
#   Sugar Content: Sweetness Descriptor:                  Style:  \
# 0          3 g/L        XD - Extra Dry   Light-bodied & Fruity
# 1          4 g/L        XD - Extra Dry   Light-bodied & Fruity
# 2          3 g/L        XD - Extra Dry    Full-bodied & Smooth
# 3          5 g/L        XD - Extra Dry  Medium-bodied & Fruity
# 4          2 g/L        XD - Extra Dry  Medium-bodied & Fruity
#
#                    Varietal:
# 0                      Blend
# 1               Valpolicella
# 2  Merlot/Cabernet Sauvignon
# 3                 Pinot Noir
# 4                    Chianti

# %%
red2=red1.rename(columns={'title': 'wine_name', 'link' : 'link','Img' :'img' , 'Bottle Size': 'bottle_size_ml', 'price': 'price', 'Alcohol/Vol:' : 'alcohol_content)', 'Made In:' : 'country', 'By:': 'winery', 'Sugar Content:': 'sugar_content_gL',
                         'Sweetness Descriptor:': 'sweetness_descr', 'Style:':'style', 'Varietal:':'varietal', 'Description': 'wine_desc'})

white2=white1.rename(columns={'title': 'Title', 'link' : 'Link', 'price': 'Price ($)', 'Alcohol/Vol:' : 'Alcohol/Vol (%)', 'Made In:' : 'Made In', 'By:': 'By', 'Sugar Content:': 'Sugar Content (g/L)',
                         'Sweetness Descriptor:': 'Sweetness Descriptor', 'Style:':'Style', 'Varietal:':'Varietal'})

# %%
red2
# Out:
#                                      wine_name  \
# 0              Mommessin Cuvee St Pierre Rouge
# 1           Folonari Valpolicella Classico DOC
# 2                Mouton Cadet Bordeaux Red AOC
# 3                         Flat Rock Pinot Noir
# 4                              Ruffino Chianti
# ...                                        ...
# 2395     Domaine Langlois-Château Saumur Rouge
# 2396  Leconfield Coonawarra Cabernet Sauvignon
# 2397      Ràjo Valpolicella Classico Superiore
# 2398                             Haywire Gamay
# 2399                     Château Terre Blanque
#
#                                                    link    price  \
# 0     https://www.lcbo.com/webapp/wcs/stores/servlet...    $8.30
# 1     https://www.lcbo.com/webapp/wcs/stores/servlet...   $14.80
# 2     https://www.lcbo.com/webapp/wcs/stores/servlet...   $17.35
# 3     https://www.lcbo.com/webapp/wcs/stores/servlet...   $22.95
# 4     https://www.lcbo.com/webapp/wcs/stores/servlet...   $15.30
# ...                                                 ...      ...
# 2395  https://www.lcbo.com/webapp/wcs/stores/servlet...   $18.95
# 2396  https://www.lcbo.com/webapp/wcs/stores/servlet...  $111.11
# 2397  https://www.lcbo.com/webapp/wcs/stores/servlet...  $111.11
# 2398  https://www.lcbo.com/webapp/wcs/stores/servlet...   $35.95
# 2399  https://www.lcbo.com/webapp/wcs/stores/servlet...   $17.95
#
#                                                     img  \
# 0     /content/dam/lcbo/products/000513.jpg/jcr:cont...
# 1     /content/dam/lcbo/products/000828.jpg/jcr:cont...
# 2     /content/dam/lcbo/products/000943.jpg/jcr:cont...
# 3     /content/dam/lcbo/products/001545.jpg/jcr:cont...
# 4     /content/dam/lcbo/products/001743.jpg/jcr:cont...
# ...                                                 ...
# 2395  /content/dam/lcbo/products/018157.jpg/jcr:cont...
# 2396  /content/dam/lcbo/products/018476.jpg/jcr:cont...
# 2397  /content/dam/lcbo/products/017675.jpg/jcr:cont...
# 2398  /content/dam/lcbo/products/019879.jpg/jcr:cont...
# 2399  /content/dam/lcbo/products/018577.jpg/jcr:cont...
#
#                                               wine_desc bottle_size_ml  \
# 0     This red blend is pale ruby in colour and offe...  750 mL bottle
# 1     Valpolicella is the classic red wine of Italy'...  750 mL bottle
# 2     From France's leading wine family, a wine that...  750 mL bottle
# 3     Innovative Flat Rock Cellars specializes in cr...  750 mL bottle
# 4     Ruffino's original wine, and one of the world'...  750 mL bottle
# ...                                                 ...            ...
# 2395                                                NaN  750 mL bottle
# 2396                                                NaN  750 mL bottle
# 2397                                                NaN  750 mL bottle
# 2398                                                NaN  750 mL bottle
# 2399                                                NaN  750 mL bottle
#
#      alcohol_content)           country                             winery  \
# 0                 12%            France                     Mommessin S.A.
# 1               12.5%     Veneto, Italy                    Folonari S.P.A.
# 2                 13%  Bordeaux, France  Baron Philippe De Rothschild S.A.
# 3                 13%   Ontario, Canada                  Flat Rock Cellars
# 4                 13%    Tuscany, Italy                     Ruffino S.R.L.
# ...               ...               ...                                ...
# 2395            12.5%            France                   Langlois Chateau
# 2396            14.5%         Australia          Leconfield Wines Pty Ltd.
# 2397              13%             Italy       Casa Vinicola Gerardo Cesari
# 2398            12.5%            Canada      Okanagan Crush Pad Winery Ltd
# 2399              14%            France                     Sas Corlianges
#
#      sugar_content_gL sweetness_descr                   style  \
# 0               3 g/L  XD - Extra Dry   Light-bodied & Fruity
# 1               4 g/L  XD - Extra Dry   Light-bodied & Fruity
# 2               3 g/L  XD - Extra Dry    Full-bodied & Smooth
# 3               5 g/L  XD - Extra Dry  Medium-bodied & Fruity
# 4               2 g/L  XD - Extra Dry  Medium-bodied & Fruity
# ...               ...             ...                     ...
# 2395            2 g/L             NaN  Medium-bodied & Fruity
# 2396              NaN             NaN      Full-bodied & Firm
# 2397              NaN             NaN  Medium-bodied & Fruity
# 2398            2 g/L             NaN   Light-bodied & Fruity
# 2399            3 g/L             NaN  Medium-bodied & Fruity
#
#                        varietal
# 0                         Blend
# 1                  Valpolicella
# 2     Merlot/Cabernet Sauvignon
# 3                    Pinot Noir
# 4                       Chianti
# ...                         ...
# 2395         Gamay (Beaujolais)
# 2396         Cabernet Sauvignon
# 2397              Blend - Other
# 2398         Gamay (Beaujolais)
# 2399              Blend - Other
#
# [2400 rows x 13 columns]

# %%
red2['price'] =red2['price'].str.replace('$','').replace('$', '')
red2['alcohol_content'] =red2['alcohol_content'].str.replace('%','')
red2['Sugar Content (g/L)'] =red2['Sugar Content (g/L)'].str.replace('g/L','')

white2['Price ($)'] =red2['Price ($)'].str.replace('$','').replace('$', '')
white2['Alcohol/Vol (%)'] =red2['Alcohol/Vol (%)'].str.replace('%','')
white2['Sugar Content (g/L)'] =red2['Sugar Content (g/L)'].str.replace('g/L','')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price ($)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-beaf9f298386> in <module>
# ----> 1 red2['Price ($)'] =red2['Price ($)'].str.replace('$','').replace('$', '')
#       2 red2['Alcohol/Vol (%)'] =red2['Alcohol/Vol (%)'].str.replace('%','')
#       3 red2['Sugar Content (g/L)'] =red2['Sugar Content (g/L)'].str.replace('g/L','')
#       4
#       5 white2['Price ($)'] =red2['Price ($)'].str.replace('$','').replace('$', '')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price ($)'

# %%
red2['price'] =red2['price'].str.replace(',', '')
white2['price'] =white2['price'].str.replace(',', '')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-bd45007c98df> in <module>
#       1 red2['price'] =red2['price'].str.replace(',', '')
# ----> 2 white2['price'] =white2['price'].str.replace(',', '')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'

# %%
red2['Price ($)'] = red2['Price ($)'].str[:5]
white2['Price ($)'] = white2['Price ($)'].str[:5]

# %%
red2[["Price ($)", "Alcohol/Vol (%)", 'Sugar Content (g/L)']] =red2[["Price ($)", "Alcohol/Vol (%)", 'Sugar Content (g/L)']].apply(pd.to_numeric)
white2[["Price ($)", "Alcohol/Vol (%)", 'Sugar Content (g/L)']] =white2[["Price ($)", "Alcohol/Vol (%)", 'Sugar Content (g/L)']].apply(pd.to_numeric)

# %%
white2.dtypes
# Out:
# Title                    object
# Link                     object
# Price ($)               float64
# Img                      object
# Description              object
# Bottle Size              object
# Alcohol/Vol (%)         float64
# Made In                  object
# By                       object
# Sugar Content (g/L)     float64
# Sweetness Descriptor     object
# Style                    object
# Varietal                 object
# dtype: object

# %%
final_red=red2[['']]
# Out:
#                                          Title  \
# 0              Mommessin Cuvee St Pierre Rouge
# 1           Folonari Valpolicella Classico DOC
# 2                Mouton Cadet Bordeaux Red AOC
# 3                         Flat Rock Pinot Noir
# 4                              Ruffino Chianti
# ...                                        ...
# 2395     Domaine Langlois-Château Saumur Rouge
# 2396  Leconfield Coonawarra Cabernet Sauvignon
# 2397      Ràjo Valpolicella Classico Superiore
# 2398                             Haywire Gamay
# 2399                     Château Terre Blanque
#
#                                                    Link  Price ($)  \
# 0     https://www.lcbo.com/webapp/wcs/stores/servlet...       8.30
# 1     https://www.lcbo.com/webapp/wcs/stores/servlet...      14.80
# 2     https://www.lcbo.com/webapp/wcs/stores/servlet...      17.35
# 3     https://www.lcbo.com/webapp/wcs/stores/servlet...      22.95
# 4     https://www.lcbo.com/webapp/wcs/stores/servlet...      15.30
# ...                                                 ...        ...
# 2395  https://www.lcbo.com/webapp/wcs/stores/servlet...      18.95
# 2396  https://www.lcbo.com/webapp/wcs/stores/servlet...     111.10
# 2397  https://www.lcbo.com/webapp/wcs/stores/servlet...     111.10
# 2398  https://www.lcbo.com/webapp/wcs/stores/servlet...      35.95
# 2399  https://www.lcbo.com/webapp/wcs/stores/servlet...      17.95
#
#                                                     Img  \
# 0     /content/dam/lcbo/products/000513.jpg/jcr:cont...
# 1     /content/dam/lcbo/products/000828.jpg/jcr:cont...
# 2     /content/dam/lcbo/products/000943.jpg/jcr:cont...
# 3     /content/dam/lcbo/products/001545.jpg/jcr:cont...
# 4     /content/dam/lcbo/products/001743.jpg/jcr:cont...
# ...                                                 ...
# 2395  /content/dam/lcbo/products/018157.jpg/jcr:cont...
# 2396  /content/dam/lcbo/products/018476.jpg/jcr:cont...
# 2397  /content/dam/lcbo/products/017675.jpg/jcr:cont...
# 2398  /content/dam/lcbo/products/019879.jpg/jcr:cont...
# 2399  /content/dam/lcbo/products/018577.jpg/jcr:cont...
#
#                                             Description    Bottle Size  \
# 0     This red blend is pale ruby in colour and offe...  750 mL bottle
# 1     Valpolicella is the classic red wine of Italy'...  750 mL bottle
# 2     From France's leading wine family, a wine that...  750 mL bottle
# 3     Innovative Flat Rock Cellars specializes in cr...  750 mL bottle
# 4     Ruffino's original wine, and one of the world'...  750 mL bottle
# ...                                                 ...            ...
# 2395                                                NaN  750 mL bottle
# 2396                                                NaN  750 mL bottle
# 2397                                                NaN  750 mL bottle
# 2398                                                NaN  750 mL bottle
# 2399                                                NaN  750 mL bottle
#
#       Alcohol/Vol (%)           Made In                                 By  \
# 0                12.0            France                     Mommessin S.A.
# 1                12.5     Veneto, Italy                    Folonari S.P.A.
# 2                13.0  Bordeaux, France  Baron Philippe De Rothschild S.A.
# 3                13.0   Ontario, Canada                  Flat Rock Cellars
# 4                13.0    Tuscany, Italy                     Ruffino S.R.L.
# ...               ...               ...                                ...
# 2395             12.5            France                   Langlois Chateau
# 2396             14.5         Australia          Leconfield Wines Pty Ltd.
# 2397             13.0             Italy       Casa Vinicola Gerardo Cesari
# 2398             12.5            Canada      Okanagan Crush Pad Winery Ltd
# 2399             14.0            France                     Sas Corlianges
#
#       Sugar Content (g/L) Sweetness Descriptor                   Style  \
# 0                     3.0       XD - Extra Dry   Light-bodied & Fruity
# 1                     4.0       XD - Extra Dry   Light-bodied & Fruity
# 2                     3.0       XD - Extra Dry    Full-bodied & Smooth
# 3                     5.0       XD - Extra Dry  Medium-bodied & Fruity
# 4                     2.0       XD - Extra Dry  Medium-bodied & Fruity
# ...                   ...                  ...                     ...
# 2395                  2.0                  NaN  Medium-bodied & Fruity
# 2396                  NaN                  NaN      Full-bodied & Firm
# 2397                  NaN                  NaN  Medium-bodied & Fruity
# 2398                  2.0                  NaN   Light-bodied & Fruity
# 2399                  3.0                  NaN  Medium-bodied & Fruity
#
#                        Varietal
# 0                         Blend
# 1                  Valpolicella
# 2     Merlot/Cabernet Sauvignon
# 3                    Pinot Noir
# 4                       Chianti
# ...                         ...
# 2395         Gamay (Beaujolais)
# 2396         Cabernet Sauvignon
# 2397              Blend - Other
# 2398         Gamay (Beaujolais)
# 2399              Blend - Other
#
# [2400 rows x 13 columns]

# %%
# step3
# load dataframe into database
pandas_gbq.to_gbq(red2, 'wine_dataset.LCBOWines', if_exists='append', project_id=projectID, credentials=credentials)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# <ipython-input-16-68524077f6f5> in <module>
#       1 # step3
#       2 # load dataframe into database
# ----> 3 pandas_gbq.to_gbq(red2, 'wine_dataset.LCBOWines', if_exists='append', project_id=projectID, credentials=credentials)
#
# ~\anaconda3\lib\site-packages\pandas_gbq\gbq.py in to_gbq(dataframe, destination_table, project_id, chunksize, reauth, if_exists, auth_local_webserver, table_schema, location, progress_bar, credentials, verbose, private_key)
#    1185                 original_schema, table_schema
#    1186             ):
# -> 1187                 raise InvalidSchema(
#    1188                     "Please verify that the structure and "
#    1189                     "data types in the DataFrame match the "
#
# InvalidSchema: Please verify that the structure and data types in the DataFrame match the schema of the destination table.
